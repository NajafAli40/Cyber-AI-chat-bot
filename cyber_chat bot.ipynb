# %%
import nltk
nltk.download('punkt', quiet=True)
nltk.download('punkt_tab', quiet=True)
from nltk.tokenize import word_tokenize
from IPython.display import display, HTML
import ipywidgets as widgets

# ============================================================
# Knowledge Base (250+ Keywords)
# ============================================================

knowledge_base = {

    # --- IDENTITY ---
    "who":          "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "created":      "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "made":         "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "built":        "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "creator":      "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "developer":    "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "developed":    "🤖 Created by Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n   BS Cyber Security | AI Project | Sir Syed CASE Institute of Technology",
    "name":         "🛡️ I am CyberSafe Bot! Created by Najaf Ali & M. Tayyab.",
    "najaf":        "👨‍💻 Najaf Ali (2430-0040) is one of my creators!",
    "tayyab":       "👨‍💻 M. Tayyab (2430-0073) is one of my creators!",
    "bot":          "🤖 I am CyberSafe Bot, your cybersecurity awareness assistant!",
    "purpose":      "🎯 My purpose is to educate people about cybersecurity and online safety!",
    "project":      "📚 This is an AI project for BS Cyber Security at Sir Syed CASE Institute of Technology.",
    "about":        "🛡️ CyberSafe Bot helps you learn about cybersecurity threats and how to stay safe online!",

    # --- GREETINGS ---
    "hello":        "👋 Hello! I'm CyberSafe Bot. Ask me anything about cybersecurity!",
    "hi":           "👋 Hi there! Ready to learn about cybersecurity? Ask me anything!",
    "hey":          "👋 Hey! I'm here to help you stay safe online. What would you like to know?",
    "good":         "😊 Great! How can I help you with cybersecurity today?",
    "morning":      "🌅 Good morning! Stay cyber safe today. Ask me anything!",
    "evening":      "🌆 Good evening! Let's talk cybersecurity. What would you like to know?",
    "thanks":       "😊 You're welcome! Stay safe online and keep learning about cybersecurity!",
    "thank":        "😊 You're welcome! Stay safe online and keep learning about cybersecurity!",
    "bye":          "👋 Goodbye! Stay safe online. Remember: Think before you click!",
    "goodbye":      "👋 Goodbye! Stay cyber safe. Najaf Ali & M. Tayyab wish you safe browsing!",

    # --- HELP ---
    "help":         "💡 Ask me about: phishing, malware, password, vpn, firewall, ransomware, 2fa, encryption, scam, hacking, privacy, darkweb, and much more!",
    "topics":       "📋 Topics: Phishing, Malware, Passwords, Hacking, VPN, Firewall, Ransomware, Encryption, Privacy, Social Engineering, Dark Web, Cyber Laws, and more!",
    "tip":          "✅ Tip: Never share passwords, always use 2FA, and keep software updated!",
    "tips":         "✅ Top tips: Strong passwords + 2FA + VPN on public WiFi + regular backups = Stay Safe!",
    "advice":       "💡 Best advice: Use strong passwords, enable 2FA, keep software updated, and never click suspicious links!",
    "guide":        "📖 Cybersecurity guide: 1) Strong passwords 2) Enable 2FA 3) Use VPN 4) Update software 5) Backup data regularly.",
    "learn":        "📚 You can learn cybersecurity from: Coursera, Cybrary, TryHackMe, HackTheBox, and YouTube tutorials!",
    "start":        "🚀 Start with basics: Learn about phishing, malware, strong passwords, and 2FA first!",

    # --- PHISHING ---
    "phishing":     "⚠️ Phishing is a fake email/message trick to steal your info. Never click suspicious links!",
    "spear":        "⚠️ Spear phishing targets specific people using personal info. Always verify the sender!",
    "smishing":     "⚠️ Smishing is phishing via SMS text messages. Don't click links in unknown texts!",
    "vishing":      "⚠️ Vishing is voice phishing over phone calls. Never give personal info to unknown callers!",
    "whaling":      "⚠️ Whaling targets high-level executives like CEOs. Extra caution needed for important people!",
    "pharming":     "⚠️ Pharming redirects you to fake websites even with correct URL. Always check the site carefully!",
    "clone":        "⚠️ Clone phishing copies legitimate emails with malicious links. Double-check every email!",
    "deceptive":    "⚠️ Deceptive phishing mimics trusted companies. Look for spelling errors and suspicious domains!",
    "angler":       "⚠️ Angler phishing happens on social media through fake customer service accounts. Be careful!",

    # --- PASSWORDS ---
    "password":     "🔑 Use strong passwords with uppercase, lowercase, numbers & symbols. Never reuse passwords!",
    "passwords":    "🔑 Use strong passwords with uppercase, lowercase, numbers & symbols. Never reuse passwords!",
    "weak":         "🔑 Weak passwords like '123456' or 'password' are easily hacked. Use a password manager!",
    "strong":       "🔑 A strong password is at least 12 characters with mixed letters, numbers, and symbols.",
    "manager":      "🔑 A password manager stores all your passwords securely. Examples: LastPass, Bitwarden, 1Password.",
    "passphrase":   "🔑 A passphrase is a sentence used as a password. Example: 'Sun$Rises@7AM!' - long and strong!",
    "reset":        "🔑 Reset your password immediately if you suspect it's been compromised. Use a unique new one!",
    "reuse":        "🔑 Never reuse passwords across multiple sites. A breach on one site exposes all your accounts!",
    "change":       "🔑 Change passwords regularly, especially after a data breach. Use unique passwords each time!",
    "default":      "⚠️ Always change default passwords on routers, cameras, and IoT devices immediately!",
    "pin":          "🔑 Use a PIN with at least 6 digits. Avoid obvious PINs like 1234 or your birth year.",
    "credential":   "🔑 Protect your credentials. Never share usernames or passwords with anyone!",
    "credentials":  "🔑 Your credentials are your digital identity. Store them safely in a password manager!",

    # --- MALWARE ---
    "malware":      "🦠 Malware is harmful software. Install antivirus and avoid unknown downloads.",
    "virus":        "🦠 A computer virus attaches to files and spreads. Keep your antivirus updated!",
    "trojan":       "🦠 A Trojan disguises itself as legit software but is harmful. Only install trusted programs!",
    "spyware":      "🦠 Spyware secretly monitors your activity. Use anti-spyware tools and avoid suspicious sites.",
    "adware":       "🦠 Adware shows unwanted ads and can track you. Use an ad blocker and scan your device.",
    "worm":         "🦠 A worm spreads across networks without user action. Keep your firewall enabled!",
    "rootkit":      "🦠 A rootkit hides malware deep in your system. Use advanced security tools to detect it.",
    "keylogger":    "🦠 A keylogger records your keystrokes to steal passwords. Use 2FA and antivirus software.",
    "botnet":       "🦠 A botnet is a network of infected computers controlled by hackers. Keep systems updated!",
    "fileless":     "🦠 Fileless malware runs in memory and leaves no files. Keep OS and software updated!",
    "polymorphic":  "🦠 Polymorphic malware changes its code to avoid detection. Use advanced antivirus solutions!",
    "scareware":    "🦠 Scareware shows fake virus warnings to trick you into buying software. Ignore pop-up alerts!",
    "stalkerware":  "🦠 Stalkerware secretly monitors victims. Check your device for unknown apps regularly!",
    "cryptojacker": "🦠 Cryptojacking uses your device to mine cryptocurrency secretly. Monitor CPU usage!",
    "logic":        "🦠 A logic bomb is malware that activates on a specific condition. Regular scans help detect it.",

    # --- RANSOMWARE ---
    "ransomware":   "🔒 Ransomware locks your files and demands payment. Backup your data regularly!",
    "backup":       "💾 Always backup your data to an external drive or cloud. Protects against ransomware!",
    "backups":      "💾 Use the 3-2-1 backup rule: 3 copies, 2 different media, 1 offsite location.",
    "decrypt":      "🔒 If hit by ransomware, do NOT pay. Report to authorities and try free decryption tools!",
    "wannacry":     "🔒 WannaCry was a massive 2017 ransomware attack. Keep Windows updated to avoid such threats!",
    "locky":        "🔒 Locky ransomware spread via email attachments. Never open unknown email attachments!",
    "ryuk":         "🔒 Ryuk ransomware targets large organizations. Strong network security is essential!",
    "pay":          "🔒 Never pay ransomware attackers. Payment encourages more attacks and doesn't guarantee recovery!",

    # --- HACKING ---
    "hacking":      "💻 Hackers exploit weaknesses. Keep your software updated to stay protected.",
    "hacker":       "💻 Ethical hackers (white hats) help find vulnerabilities. Black hat hackers are criminals!",
    "exploit":      "💻 An exploit takes advantage of a software bug. Always patch and update your software!",
    "vulnerability":"💻 A vulnerability is a weakness in software. Regular updates fix known vulnerabilities.",
    "breach":       "💻 A data breach exposes private information. Change your passwords immediately if breached!",
    "social":       "💻 Social engineering tricks people into revealing info. Always verify identities before sharing.",
    "ethical":      "💻 Ethical hacking (penetration testing) is legal hacking to find security flaws. A great career!",
    "blackhat":     "💻 Black hat hackers are criminals who hack for personal gain. Their actions are illegal!",
    "whitehat":     "💻 White hat hackers are ethical security professionals who help protect systems legally.",
    "greyhat":      "💻 Grey hat hackers operate between ethical and unethical. They may hack without permission.",
    "penetration":  "💻 Penetration testing simulates attacks to find vulnerabilities. It's a key security practice!",
    "pentest":      "💻 Pentest (penetration test) evaluates your system security. Hire certified professionals!",
    "zero":         "💻 Zero-day exploits target unknown vulnerabilities. Keep systems updated to minimize risk!",
    "zeroday":      "💻 Zero-day vulnerabilities are unknown flaws. Software vendors rush to patch them when found!",
    "sql":          "💻 SQL injection inserts malicious code into databases. Developers must sanitize all inputs!",
    "injection":    "💻 Code injection attacks insert malicious code into applications. Proper input validation prevents it!",
    "xss":          "💻 Cross-Site Scripting (XSS) injects malicious scripts into websites. Keep browsers updated!",
    "csrf":         "💻 CSRF tricks users into performing unwanted actions. Websites use tokens to prevent it.",
    "brute":        "💻 Brute force attacks try every password combination. Use strong passwords and account lockouts!",
    "dictionary":   "💻 Dictionary attacks use common words as passwords. Avoid using real words in passwords!",
    "rainbow":      "💻 Rainbow table attacks crack hashed passwords. Websites should use salted password hashing.",
    "arp":          "💻 ARP poisoning redirects network traffic to an attacker. Use network monitoring tools!",
    "session":      "💻 Session hijacking steals your login session. Always logout from shared computers!",
    "clickjacking": "💻 Clickjacking tricks you into clicking hidden elements. Keep browsers and plugins updated!",

    # --- NETWORK SECURITY ---
    "vpn":          "🌐 A VPN hides your internet activity. Use one on public Wi-Fi for safety.",
    "wifi":         "🌐 Avoid using public Wi-Fi for banking. Use a VPN if necessary.",
    "firewall":     "🌐 A firewall blocks unauthorized access to your computer. Always keep it enabled.",
    "dns":          "🌐 DNS attacks redirect you to fake websites. Use secure DNS like Cloudflare (1.1.1.1).",
    "ddos":         "🌐 DDoS attacks flood servers with traffic. Businesses should use DDoS protection services.",
    "mitm":         "🌐 Man-in-the-Middle attacks intercept your communication. Use HTTPS and VPN to stay safe.",
    "sniffing":     "🌐 Packet sniffing captures your network data. Use encrypted connections always!",
    "spoofing":     "🌐 Spoofing fakes an identity (email, IP, etc). Always verify sources before trusting them.",
    "tor":          "🌐 Tor anonymizes your internet traffic. Useful for privacy but can be slow.",
    "proxy":        "🌐 A proxy server acts as a gateway between you and the internet. Use trusted proxies only!",
    "router":       "🌐 Secure your router: change default passwords, update firmware, and disable remote access!",
    "port":         "🌐 Open ports can be entry points for hackers. Close unnecessary ports on your network!",
    "protocol":     "🌐 Secure protocols like HTTPS, SSH, and SFTP protect data in transit. Always use them!",
    "ip":           "🌐 Your IP address reveals your location. Use a VPN to hide it from trackers.",
    "mac":          "🌐 MAC address identifies your device on a network. MAC spoofing can bypass some filters.",
    "network":      "🌐 Secure your network: use WPA3 encryption, strong passwords, and regular firmware updates!",
    "bandwidth":    "🌐 Unusual bandwidth usage may indicate malware. Monitor your network traffic regularly!",
    "intrusion":    "🌐 Intrusion Detection Systems (IDS) monitor networks for suspicious activity. Very important!",
    "ids":          "🌐 IDS monitors and alerts on suspicious network activity. IPS can actively block threats!",
    "ips":          "🌐 Intrusion Prevention Systems actively block network threats. Essential for business security!",
    "siem":         "🌐 SIEM systems collect and analyze security logs. Used by security teams to detect threats!",
    "honeypot":     "🌐 A honeypot is a fake system that lures attackers. Helps study hacker behavior!",

    # --- AUTHENTICATION ---
    "2fa":          "🔐 Two-Factor Authentication adds an extra login step. Always enable it!",
    "mfa":          "🔐 Multi-Factor Authentication uses 2+ verification methods. Best way to secure accounts!",
    "authentication":"🔐 Authentication verifies who you are. Use strong passwords + MFA for best protection.",
    "biometric":    "🔐 Biometrics use fingerprint or face recognition. Convenient but not 100% foolproof.",
    "otp":          "🔐 One-Time Passwords expire quickly. Use authenticator apps over SMS OTPs.",
    "authenticator":"🔐 Use apps like Google Authenticator or Authy for secure 2FA instead of SMS!",
    "token":        "🔐 Hardware security tokens like YubiKey provide strong authentication. Great for businesses!",
    "sso":          "🔐 Single Sign-On allows one login for multiple services. Secure the main account well!",
    "oauth":        "🔐 OAuth lets apps access your accounts without sharing passwords. Review app permissions!",
    "captcha":      "🔐 CAPTCHA verifies you're human. It helps prevent automated bot attacks on websites.",
    "verification": "🔐 Always verify your identity through official channels. Don't trust unsolicited verification requests!",
    "logout":       "🔐 Always logout from accounts on shared or public computers to prevent session theft!",
    "lockout":      "🔐 Account lockout after failed attempts prevents brute force attacks. Enable this feature!",

    # --- ENCRYPTION ---
    "encryption":   "🔐 Encryption scrambles data so only authorized users can read it. Always use encrypted apps!",
    "encrypted":    "🔐 Encrypted data is unreadable without the key. Look for HTTPS in websites!",
    "https":        "🔐 HTTPS means the website encrypts your data. Never enter passwords on HTTP sites!",
    "ssl":          "🔐 SSL/TLS encrypts data between you and websites. Check for the padlock icon in browser.",
    "tls":          "🔐 TLS (Transport Layer Security) is the modern encryption protocol replacing SSL.",
    "endtoend":     "🔐 End-to-end encryption means only sender and receiver can read messages. Use Signal!",
    "aes":          "🔐 AES (Advanced Encryption Standard) is the most widely used encryption algorithm today.",
    "rsa":          "🔐 RSA is a public-key encryption algorithm used to secure data transmissions.",
    "hash":         "🔐 Hashing converts data into a fixed string. Used to store passwords securely.",
    "hashing":      "🔐 Password hashing protects stored passwords. MD5 is weak; use SHA-256 or bcrypt!",
    "certificate":  "🔐 Digital certificates verify website identity. Check certificates before sharing info!",
    "pki":          "🔐 Public Key Infrastructure manages digital certificates and encryption keys.",
    "pgp":          "🔐 PGP (Pretty Good Privacy) encrypts emails and files. Great for sensitive communications!",
    "symmetric":    "🔐 Symmetric encryption uses the same key for encryption and decryption. Fast but key-sharing is risky.",
    "asymmetric":   "🔐 Asymmetric encryption uses public and private key pairs. More secure for key exchange!",

    # --- PRIVACY ---
    "privacy":      "👁️ Protect your privacy by limiting what you share online and reviewing app permissions.",
    "cookie":       "👁️ Cookies track your browsing. Clear them regularly and use private/incognito mode.",
    "cookies":      "👁️ Cookies track your browsing. Clear them regularly and use private/incognito mode.",
    "tracking":     "👁️ Online trackers follow your activity. Use Firefox with privacy settings enabled.",
    "data":         "👁️ Your personal data is valuable. Read privacy policies and limit app access!",
    "identity":     "👁️ Identity theft happens when someone steals your info. Monitor your accounts regularly!",
    "gdpr":         "👁️ GDPR is a European law protecting personal data. You have rights over your data!",
    "pii":          "👁️ PII (Personally Identifiable Information) includes your name, address, SSN. Protect it!",
    "anonymity":    "👁️ Online anonymity protects your identity. Use VPN and Tor for better privacy.",
    "fingerprint":  "👁️ Browser fingerprinting tracks you without cookies. Use privacy browsers like Brave!",
    "metadata":     "👁️ Metadata in files reveals hidden info like location and time. Strip it before sharing!",
    "doxing":       "👁️ Doxing is publishing someone's private info online. Limit what you share publicly!",
    "surveillance": "👁️ Online surveillance is widespread. Use encrypted apps and VPNs to protect yourself.",
    "incognito":    "👁️ Incognito mode doesn't hide your IP. Use a VPN for real privacy online.",
    "browser":      "🌍 Use privacy-focused browsers like Brave or Firefox with privacy extensions!",
    "extension":    "🌍 Browser extensions can be risky. Only install extensions from trusted developers!",

    # --- ANTIVIRUS & TOOLS ---
    "antivirus":    "🛡️ Antivirus software detects and removes threats. Keep it always updated!",
    "scan":         "🛡️ Regularly scan your device for threats. Schedule weekly antivirus scans.",
    "patch":        "🛡️ Software patches fix security holes. Enable auto-updates on all your devices!",
    "update":       "🛡️ Keeping software updated patches vulnerabilities. Enable automatic updates!",
    "updates":      "🛡️ Keeping software updated patches vulnerabilities. Enable automatic updates!",
    "defender":     "🛡️ Windows Defender is a built-in antivirus. Keep it enabled and updated!",
    "sandbox":      "🛡️ A sandbox runs suspicious programs safely in isolation. Used by security researchers.",
    "whitelist":    "🛡️ Whitelisting only allows approved programs to run. Great for high-security systems!",
    "blacklist":    "🛡️ Blacklisting blocks known malicious programs. Keep blacklists updated regularly!",
    "edr":          "🛡️ Endpoint Detection & Response (EDR) tools monitor devices for threats in real-time.",
    "soc":          "🛡️ Security Operations Center (SOC) monitors and responds to security incidents 24/7.",

    # --- EMAIL SECURITY ---
    "email":        "📧 Be careful with emails. Don't open attachments from unknown senders!",
    "spam":         "📧 Spam emails are unsolicited messages. Mark them as spam, never click links!",
    "attachment":   "📧 Email attachments can contain malware. Only open files from trusted senders.",
    "link":         "📧 Hover over links before clicking to see the real URL. Fake links are common!",
    "spf":          "📧 SPF (Sender Policy Framework) verifies email senders. Helps prevent email spoofing!",
    "dkim":         "📧 DKIM adds a digital signature to emails. Helps verify email authenticity.",
    "dmarc":        "📧 DMARC protects email domains from unauthorized use. Essential for businesses!",
    "phish":        "📧 If you receive a phishing email, report it to your IT team or email provider!",
    "forward":      "📧 Be careful forwarding emails with sensitive information. You never know who will see it!",
    "encrypt":      "📧 Encrypt sensitive emails using PGP or S/MIME to protect content in transit.",

    # --- SOCIAL MEDIA ---
    "facebook":     "📱 Secure Facebook: Enable 2FA, review privacy settings, and limit public info!",
    "instagram":    "📱 Secure Instagram: Use 2FA, avoid sharing your location, and use a strong password!",
    "twitter":      "📱 Secure Twitter/X: Enable 2FA and be careful what personal info you share publicly.",
    "linkedin":     "📱 LinkedIn scams are common. Verify job offers and connection requests carefully!",
    "tiktok":       "📱 TikTok collects lots of data. Review privacy settings and limit personal info shared.",
    "whatsapp":     "📱 WhatsApp has end-to-end encryption. Enable two-step verification for extra security!",
    "telegram":     "📱 Enable Telegram's Secret Chats for end-to-end encryption. Regular chats aren't encrypted!",
    "signal":       "📱 Signal is the most secure messaging app. Recommended for private communications!",
    "media":        "📱 Social media oversharing is dangerous. Don't post your location, travel plans, or daily routine!",
    "oversharing":  "📱 Oversharing on social media helps hackers. Keep personal details private!",

    # --- SAFE BROWSING ---
    "download":     "🌍 Only download software from official websites. Cracked software often has malware!",
    "safe":         "✅ Stay safe: update software, use strong passwords, enable 2FA, think before clicking!",
    "online":       "✅ Online safety is everyone's responsibility. Share cybersecurity tips with others!",
    "popup":        "🌍 Don't click on pop-ups claiming your PC is infected. These are scareware tricks!",
    "ad":           "🌍 Use an ad blocker like uBlock Origin. Malicious ads (malvertising) can infect your PC!",
    "adblock":      "🌍 Ad blockers prevent malvertising attacks. Install uBlock Origin on your browser!",
    "search":       "🌍 Use privacy search engines like DuckDuckGo to avoid being tracked by Google.",
    "website":      "🌍 Always check website URLs carefully. Fake sites use slight spelling variations to trick you!",
    "url":          "🌍 Check URLs carefully before clicking. Look for HTTPS and correct spelling!",
    "http":         "⚠️ HTTP sites are not secure. Never enter passwords or payment info on HTTP sites!",

    # --- CYBERCRIME & LEGAL ---
    "cybercrime":   "⚖️ Cybercrime includes hacking, fraud, and theft online. Report it to authorities!",
    "darkweb":      "⚖️ The dark web hosts illegal activities. Avoid it — it's dangerous and often illegal!",
    "dark":         "⚖️ The dark web requires Tor browser. Most activity there is illegal. Stay away!",
    "fraud":        "⚖️ Online fraud tricks you into losing money. Verify all online transactions carefully.",
    "scam":         "⚖️ Scams promise fake rewards to steal your info or money. If too good, it's a scam!",
    "piracy":       "⚖️ Software piracy is illegal and dangerous. Cracked software often contains malware!",
    "illegal":      "⚖️ Unauthorized hacking is illegal worldwide. Ethical hacking requires proper permission!",
    "law":          "⚖️ Cybersecurity laws like CFAA (US) and IT Act (Pakistan) criminalize unauthorized access.",
    "peca":         "⚖️ PECA (Pakistan) is Pakistan's cyber crime law. Cybercrime can lead to imprisonment!",
    "report":       "⚖️ Report cybercrime to FIA Cybercrime Wing in Pakistan or local law enforcement.",
    "fia":          "⚖️ FIA Cybercrime Wing handles cybercrime in Pakistan. Website: fia.gov.pk",
    "interpol":     "⚖️ Interpol's cybercrime unit investigates international cyber attacks globally.",

    # --- DEVICES ---
    "phone":        "📱 Secure your phone: use PIN/biometric, keep it updated, avoid unknown app installs.",
    "mobile":       "📱 Mobile devices are frequent targets. Only install apps from official stores!",
    "iot":          "📱 IoT devices can be hacked. Change default passwords and update firmware always!",
    "usb":          "💾 Unknown USB drives can contain malware. Never plug in a USB you don't trust!",
    "bluetooth":    "📡 Turn off Bluetooth when not in use. Attackers can exploit it via Bluejacking/Bluesnarfing!",
    "laptop":       "💻 Secure your laptop: use full disk encryption, strong password, and screen lock!",
    "computer":     "💻 Keep your computer updated, use antivirus, and enable the firewall at all times!",
    "printer":      "🖨️ Printers can be hacked! Update printer firmware and put them on a separate network.",
    "camera":       "📷 Webcams can be hijacked. Cover your webcam when not in use. Update device firmware!",
    "smartwatch":   "⌚ Smartwatches collect sensitive health data. Review app permissions carefully!",
    "alexa":        "🔊 Smart speakers like Alexa listen constantly. Review privacy settings and voice history.",
    "smart":        "🏠 Smart home devices are vulnerable. Use strong passwords and separate IoT network!",

    # --- CLOUD SECURITY ---
    "cloud":        "☁️ Cloud data can be breached. Use strong passwords, 2FA, and encrypt sensitive files!",
    "google":       "☁️ Secure Google account: Enable 2FA, review connected apps, and check login activity!",
    "microsoft":    "☁️ Secure Microsoft account: Enable 2FA and use Microsoft Authenticator app!",
    "dropbox":      "☁️ Secure Dropbox: Enable 2FA and regularly review shared folders and linked devices!",
    "icloud":       "☁️ Secure iCloud: Enable 2FA and use a strong unique Apple ID password!",
    "storage":      "☁️ Encrypt files before uploading to cloud storage. Use services with zero-knowledge encryption.",
    "share":        "☁️ Be careful what you share in the cloud. Misconfigured settings can expose your files!",
    "permission":   "☁️ Review app permissions regularly. Apps often request more access than they need!",
    "permissions":  "☁️ Grant only necessary permissions to apps. Revoke access from apps you no longer use!",

    # --- CAREER & CERTIFICATIONS ---
    "career":       "🎓 Cybersecurity is a great career! High demand, great salaries, and always evolving.",
    "certification":"🎓 Top certifications: CEH, CISSP, CompTIA Security+, OSCP, CISM. Start with Security+!",
    "ceh":          "🎓 CEH (Certified Ethical Hacker) is a popular certification for penetration testers.",
    "cissp":        "🎓 CISSP is an advanced certification for experienced security professionals.",
    "comptia":      "🎓 CompTIA Security+ is the best entry-level cybersecurity certification to start with!",
    "oscp":         "🎓 OSCP is a hands-on penetration testing certification. One of the most respected!",
    "tryhackme":    "🎓 TryHackMe is a great platform to practice cybersecurity skills online for free!",
    "hackthebox":   "🎓 HackTheBox is a platform for practicing ethical hacking. Great for skill building!",
    "ctf":          "🎓 CTF (Capture The Flag) competitions help develop hacking skills. Try PicoCTF!",

    # --- COMMON ATTACKS ---
    "attack":       "⚠️ Common attacks: Phishing, Malware, DDoS, MITM, SQL Injection, Brute Force. Stay protected!",
    "insider":      "⚠️ Insider threats come from employees. Limit access privileges and monitor activity.",
    "apt":          "⚠️ Advanced Persistent Threats (APT) are long-term targeted attacks by skilled hackers.",
    "supply":       "⚠️ Supply chain attacks target software vendors to reach their customers. SolarWinds was an example!",
    "watering":     "⚠️ Watering hole attacks infect websites your targets frequently visit. Keep browsers updated!",
    "typosquatting":"⚠️ Typosquatting registers misspelled domains to trap users. Always check URLs carefully!",
    "credential":   "⚠️ Credential stuffing uses leaked passwords to try other accounts. Use unique passwords!",
    "replay":       "⚠️ Replay attacks reuse intercepted data to authenticate. Use session tokens to prevent it!",
    "overflow":     "⚠️ Buffer overflow attacks corrupt memory to run malicious code. Keep software updated!",

    # --- INCIDENT RESPONSE ---
    "incident":     "🚨 If hacked: disconnect from internet, change passwords, scan for malware, report it!",
    "response":     "🚨 Incident response steps: Identify, Contain, Eradicate, Recover, and Learn from the attack.",
    "forensics":    "🔍 Digital forensics investigates cybercrimes by analyzing digital evidence.",
    "recovery":     "🔄 Recovery after attack: restore from backup, patch vulnerabilities, update all passwords.",
    "contain":      "🚨 Contain a breach immediately: isolate affected systems to prevent further spread!",
    "investigate":  "🔍 Investigate security incidents thoroughly to understand what happened and prevent recurrence.",

    # --- GENERAL SECURITY ---
    "security":     "🛡️ Cybersecurity protects systems, networks, and data from digital attacks. Stay informed!",
    "cyber":        "🛡️ Cyber threats are constantly evolving. Stay updated with the latest security news!",
    "awareness":    "🛡️ Cybersecurity awareness is the first line of defense. Share knowledge with others!",
    "risk":         "⚠️ Risk management identifies and reduces cybersecurity risks. Assess and mitigate them!",
    "threat":       "⚠️ Cyber threats include malware, phishing, hacking, and insider threats. Stay vigilant!",
    "threats":      "⚠️ Common threats: Phishing, Ransomware, Malware, DDoS, Insider Threats, APT.",
    "defense":      "🛡️ Defense in depth uses multiple security layers. No single tool protects everything!",
    "zero trust":   "🛡️ Zero Trust security means 'never trust, always verify'. Verify every access request!",
    "patch":        "🛡️ Patch management keeps software updated. Unpatched systems are easy targets!",
    "audit":        "🛡️ Security audits identify vulnerabilities in systems. Conduct them regularly!",
    "compliance":   "🛡️ Security compliance ensures you meet legal requirements like GDPR, HIPAA, PCI-DSS.",
    "hipaa":        "🛡️ HIPAA protects health data in the US. Healthcare organizations must comply!",
    "pcidss":       "🛡️ PCI-DSS protects payment card data. All businesses handling cards must comply!",
    "iso":          "🛡️ ISO 27001 is the international standard for information security management.",
    "nist":         "🛡️ NIST Cybersecurity Framework provides guidelines for managing cybersecurity risk.",
}

# ============================================================
# Creator Response
# ============================================================

CREATOR_RESPONSE = (
    "🤖 I was created by:\n"
    "============================================================\n"
    "   CyberSafe Bot - Cybersecurity Awareness Chatbot\n"
    "   BS Cyber Security | AI Project\n"
    "   Najaf Ali (2430-0040) & M. Tayyab (2430-0073)\n"
    "============================================================\n"
    "   Submitted to: Ma'am Salma Asif\n"
    "   Sir Syed CASE Institute of Technology"
)

# ============================================================
# Response Function
# ============================================================

def get_response(user_input):
    user_lower = user_input.lower()
    tokens = word_tokenize(user_lower)

    creator_triggers = [
        "who made you", "who created you", "who built you",
        "who developed you", "your creator", "who are you",
        "who is your creator", "who made this", "who are your developers"
    ]
    for trigger in creator_triggers:
        if trigger in user_lower:
            return CREATOR_RESPONSE

    for token in tokens:
        if token in knowledge_base:
            return knowledge_base[token]

    for keyword, response in knowledge_base.items():
        if keyword in user_lower:
            return response

    return ("❓ I don't have info on that yet.\n"
            "💡 Try: phishing, malware, password, ransomware, hacking,\n"
            "   vpn, firewall, antivirus, 2fa, encryption, scam,\n"
            "   darkweb, privacy, career, cloud, or type 'help'!")

# ============================================================
# Chat UI (Instant - No Flask/Ngrok needed)
# ============================================================

display(HTML("""
<div style="
  background: linear-gradient(135deg, #0d1b2a, #1b2a3b);
  border: 2px solid #00ff88;
  border-radius: 12px;
  padding: 16px;
  text-align: center;
  margin-bottom: 10px;
">
  <h2 style="color:#00ff88; margin:0; font-size:22px;">🛡️ CyberSafe Bot</h2>
  <p style="color:#aaa; margin:6px 0 0 0; font-size:13px;">
    BS Cyber Security | AI Project &nbsp;|&nbsp;
    Najaf Ali (2430-0040) &amp; M. Tayyab (2430-0073)
  </p>
  <p style="color:#666; margin:4px 0 0 0; font-size:11px;">
    Submitted to: Ma'am Salma Asif &nbsp;|&nbsp; Sir Syed CASE Institute of Technology
  </p>
</div>
"""))

chat_output = widgets.Output(layout=widgets.Layout(
    border='1px solid #00ff8844',
    min_height='350px',
    max_height='420px',
    overflow_y='auto',
    padding='10px',
))

user_input_box = widgets.Text(
    placeholder='Ask anything: phishing, malware, 2fa, vpn, who made you...',
    layout=widgets.Layout(width='80%', height='40px')
)

send_button = widgets.Button(
    description='Send 🚀',
    button_style='success',
    layout=widgets.Layout(width='18%', height='40px')
)

with chat_output:
    display(HTML("""
    <div style="background:#1a2a3a; border-left:3px solid #00ff88;
                padding:10px; border-radius:8px; margin:5px 0;">
      <b style="color:#00ff88;">🤖 CyberSafe Bot:</b><br>
      <span style="color:#e0e0e0;">
        👋 Hello! I'm CyberSafe Bot with 250+ cybersecurity topics!<br>
        Try asking about: <i>phishing, malware, password, vpn, 2fa,
        ransomware, encryption, darkweb, career, cloud</i><br>
        Or type <b>'help'</b> for all topics. Type <b>'tips'</b> for quick safety tips!
      </span>
    </div>
    """))

def on_send(b):
    user_text = user_input_box.value.strip()
    if not user_text:
        return
    user_input_box.value = ''
    response = get_response(user_text)
    response_html = response.replace('\n', '<br>')
    with chat_output:
        display(HTML(f"""
        <div style="text-align:right; margin:5px 0;">
          <span style="background:#00ff88; color:#000;
                       padding:8px 14px; border-radius:16px;
                       display:inline-block; max-width:80%;
                       text-align:left; font-size:13px;">
            <b>🧑 You:</b> {user_text}
          </span>
        </div>
        <div style="background:#1a2a3a; border-left:3px solid #00ff88;
                    padding:10px; border-radius:8px; margin:5px 0;
                    max-width:85%; font-size:13px;">
          <b style="color:#00ff88;">🤖 Bot:</b><br>
          <span style="color:#e0e0e0;">{response_html}</span>
        </div>
        """))

send_button.on_click(on_send)
user_input_box.on_submit(on_send)

display(widgets.VBox([
    chat_output,
    widgets.HBox([user_input_box, send_button])
]))

print(f"\n✅ CyberSafe Bot is ready! ({len(knowledge_base)} topics loaded)")
print("💡 Type your question above and press Enter or click Send 🚀")
# Out:
# <div style="
#   background: linear-gradient(135deg, #0d1b2a, #1b2a3b);
#   border: 2px solid #00ff88;
#   border-radius: 12px;
#   padding: 16px;
#   text-align: center;
#   margin-bottom: 10px;
# ">
#   <h2 style="color:#00ff88; margin:0; font-size:22px;">🛡️ CyberSafe Bot</h2>
#   <p style="color:#aaa; margin:6px 0 0 0; font-size:13px;">
#     BS Cyber Security | AI Project &nbsp;|&nbsp;
#     Najaf Ali (2430-0040) &amp; M. Tayyab (2430-0073)
#   </p>
#   <p style="color:#666; margin:4px 0 0 0; font-size:11px;">
#     Submitted to: Ma'am Salma Asif &nbsp;|&nbsp; Sir Syed CASE Institute of Technology
#   </p>
# </div>
# ...
# ✅ CyberSafe Bot is ready! (278 topics loaded)
# 💡 Type your question above and press Enter or click Send 🚀
